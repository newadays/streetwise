# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata
import requests

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

url = "https://data.cityofchicago.org/resource/kf7e-cur8.json?$where=time between '2018-01-01T12:00:00' and '2018-10-11T14:00:00'"

headers = {
    'X-App-Token': "baRUbRLnaRUQk8RGJXpA2ezoV"
    }

r = requests.request("GET", url, headers=headers)


# Example authenticated client (needed for non-public datasets):
# client = Socrata("data.cityofchicago.org",
#                  "baRUbRLnaRUQk8RGJXpA2ezoV",
#                  username="segunawodokun@gmail.com",
#                  password="Wale123@")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.

# x = r.json()
# df = pd.DataFrame(x['teams'])
results = r.json()
# results = client.get("m65n-ux8y", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df.head(100)
# Out:
#    bus_count day_of_week                                      description  \
# 0         26           5       North Ave to Diversy. Cicero to Ravenswood
# 1         34           5  North Ave to Montrose. Ravenswood to Lake Shore
# 2         48           5       Roosevelt to North Ave. Cicero to Rockwell
# 3         15           5            Wacker to North. Halsted to  Michigan
# 4         31           5         Roosevelt to Wacker: Halsted to Michigan
# 5         30           5          Pershing to Roosevel. Cicero to Western
# 6         21           5         Pershing to Roosevel. Western to Stewart
# 7         61           7         Roosevelt to Wacker: Halsted to Michigan
# 8         40           7          Pershing to Roosevel. Cicero to Western
# 9         34           7         Pershing to Roosevel. Western to Stewart
# 10        45           7              71st to Pershing. Cicero to Western
# 11        43           7    71st to Pershing. Cottage Grove to Lake Shore
# ...
